# %%
import pandas as pd

# %%
df_fire = pd.read_csv('Resources/California_Fire_Incidents_Uncleaned.csv')
df_fire.head(100)
# Out:
#     AcresBurned  Active                                          AdminUnit  \
# 0      257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1       30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2       27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3       27440.0   False                              Tahoe National Forest
# 4       24251.0   False                       Ventura County Fire/CAL FIRE
# ..          ...     ...                                                ...
# 95         92.0   False                                CAL FIRE Butte Unit
# 96         91.0   False               CAL FIRE Madera-Mariposa-Merced Unit
# 97         90.0   False                    CAL FIRE/Riverside County Fire
# 98         85.0   False                           CAL FIRE San Luis Obispo
# 99         82.0   False                            CAL FIRE Mendocino Unit
#
#     AirTankers  ArchiveYear  CalFireIncident  \
# ...

# %%
df_fire_c = df_fire[['AcresBurned','Counties','CountyIds','Latitude','Longitude']]
df_fire_c.head()
# Out:
#    AcresBurned     Counties CountyIds   Latitude   Longitude
# 0     257314.0     Tuolumne        55  37.857000 -120.086000
# 1      30274.0  Los Angeles        19  34.585595 -118.423176
# 2      27531.0    Riverside        33  33.709500 -116.728850
# 3      27440.0       Placer        31  39.120000 -120.650000
# 4      24251.0      Ventura        56   0.000000    0.000000

# %%
df_fire_c.to_csv('California_Fire_Incidents_Cleaned.csv')

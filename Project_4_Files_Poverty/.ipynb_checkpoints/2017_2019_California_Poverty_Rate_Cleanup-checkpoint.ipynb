# %%
#URL of dataset
url = 'https://data.census.gov/table?q=DP03&g=010XX00US_040XX00US06'

# %%
#Import dependancies
import pandas as pd
import numpy as np
from os import path

# %%
#Path to csv files
path_2017 = '../Project_4_Files_Poverty/ACSDP1Y2017.DP03-Data.csv'
path_2018 = '../Project_4_Files_Poverty/ACSDP1Y2018.DP03-Data.csv'
path_2019 = '../Project_4_Files_Poverty/ACSDP1Y2019.DP03-Data.csv'

# %%
#Create a dataframe from the read csv
df_2017 = pd.DataFrame(pd.read_csv(path_2017, skiprows=1))
df_2018 = pd.DataFrame(pd.read_csv(path_2018, skiprows=1))
df_2019 = pd.DataFrame(pd.read_csv(path_2019, skiprows=1))

df_2017.head()
# Out:
#      Geography Geographic Area Name  \
# 0    0100000US        United States
# 1  0400000US06           California
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                          260564248
# 1                                           31510759
#
#    Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                              51178
# 1                                              11155
#
#    Percent!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                          260564248
# 1                                           31510759
#
#   Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                                (X)
# 1                                                (X)
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 0                                          164727057
# ...

# %%
#List of dataframes
df_list = [df_2017, df_2018, df_2019]
df2_list = []
df3_list = []
means = []

#List of years
years = ['2017', '2018', '2019']

#Loop through DF and add a column year
for df in df_list:

    df2 = df.replace('NaN',0)

    #Find the row containing California
    temp_df = df2[df2['Geographic Area Name'].isin(['California'])]

    #Loop through dfs in order to elimate the unnecessary columns
    temp_df = temp_df.filter(regex='Percent').filter(regex='POVERTY')

    #Add only the California Geography to a new df list
    df2_list.append(temp_df)

#add a column for the year
for i in range(0,len(years)):
    temp_df = df2_list[i]
    temp_df['Year'] = years[i]
    df3_list.append(temp_df)



    #temp_df = temp_df.mean()
    #temp_df['Mean Percentage %'] = temp_df[~np.isnan(temp_df)].mean()
    #means = [np.mean(col[~np.isnan(col)]) for col in temp_df]
#Create a conbined dataframe form the df list
#combined_df = pd.concat(new_df)

#combined_df.head()

# %%
df2_list[2].head()
# Out:
#    Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families  \
# 1                                                8.2
#
#    Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families  \
# 1                                                0.2
#
#    Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years  \
# 1                                               12.4
#
#    Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years  \
# 1                                                0.3
#
# ...

# %%
df3_list[2].head()
# Out:
#    Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families  \
# 1                                                8.2
#
#    Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families  \
# 1                                                0.2
#
#    Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years  \
# 1                                               12.4
#
#    Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families!!With related children of the householder under 18 years  \
# 1                                                0.3
#
# ...

# %%
df_list[2].head()
# Out:
#      Geography Geographic Area Name  \
# 0    0100000US        United States
# 1  0400000US06           California
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                          263534161
# 1                                           31617786
#
#    Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 0                                              52161
# 1                                              11444
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 0                                          167501734
# 1                                           20246507
#
#    Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 0                                             160564
# 1                                              39645
#
#    Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force  \
# ...

# %%
#Get rid of margin of error
#There are duplicates, get rid of them
#Unnamed:500 
#Get rid off Employement status pop 16 years and over
#get rid of in labor force 
#Civilian labor force employed
#Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!65 years and over
#Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Unrelated individuals 15 years and over
#Percent Margin of Error!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!Unrelated individuals 15 years and over

# %%
keep_columns= [
'Geography',
'Geographic Area Name',
'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force!!Civilian labor force!!Employed',
'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!18 years and over!!18 to 64 years',
'Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All people!!People in families',
]

df_2017_clean = pd.DataFrame(df_2017, columns=keep_columns)
df_2018_clean = pd.DataFrame(df_2018, columns=keep_columns)
df_2019_clean = pd.DataFrame(df_2019, columns=keep_columns)

# %%
df_2017_clean.info()
df_2018_clean.info()
df_2019_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                   --------------  -----
#  0   Geography                                                                                                                                                2 non-null      object
#  1   Geographic Area Name                                                                                                                                     2 non-null      object
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/lleiva25/Project4/blob/main/Project4_Merging_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import Dependencies
import pandas as pd

# %%
#Path to the files
path1 = '/content/drive/MyDrive/Project4/2017-2019_California_Agriculture_Census_Cleaned.csv'
path2 = '/content/drive/MyDrive/Project4/California_Fire_Incidents_Cleaned.csv'
path3 = '/content/drive/MyDrive/Project4/2017-2019_California_Important_Farmland_Most_Recent.csv'


#Read and turn files into dataframe
df1 = pd.DataFrame(pd.read_csv(path1,index_col=0))
df2 = pd.DataFrame(pd.read_csv(path2,index_col=0))
df3 = pd.DataFrame(pd.read_csv(path3,index_col=0))

# %%
#Put dataframe in range of 2017-2019 for df2 & df3
years = [2013,2014,2015,2016,2020]

for year in years:
  df2 = df2[df2['ArchiveYear'] != year]
  df3 = df3[df3['Updated_Year'] != year]

#Drop values that have a ","
list_commas = ['42,56','28,49','28,48','27,40','6,11,17,23','45,53', '19,56', '28,57', '6,17,23','62,37']
for comma in list_commas:
  df2 = df2[df2['CountyIds'] != comma]

#Rename 'County's Name' to 'Counties'
df1 = df1.rename(columns={' County Code' : 'CountyIds'})
df3 = df3.rename(columns={"County's Name" : 'Counties',
                          'Updated_Year':'ArchiveYear'})

#Drop "State of Oregon" & 'State of Nevada' from Counties
states = ["State of Oregon",'State of Nevada']
for state in states:
  df3 = df3[df3["Counties"] != state]

#Drop df3 columns
df3 = df3.drop(columns= ['Object_ID', 'Code','Length of Area (acres)', 'Meta_data_link'])

# %%
df1.head()
# Out:
#     Year  CountyIds     Crop Name   Production   Unit  Price P/I ($)  \
# 16  2017          7  ALMONDS ALL       29700.0  Tons            0.16
# 18  2017         11  ALMONDS ALL       64200.0  Tons            0.07
# 19  2017         19  ALMONDS ALL      258000.0  Tons            0.02
# 20  2017         21  ALMONDS ALL       44200.0  Tons            0.11
# 21  2017         29  ALMONDS ALL      264000.0  Tons            0.02
#
#      Price P/U  Total Value($)
# 16     4653.03    1.381950e+08
# 18     4785.64    3.072380e+08
# 19     4526.00    1.167708e+09
# 20     4912.22    2.171200e+08
# 21     4676.98    1.234724e+09

# %%
df2.head()
# Out:
#      AcresBurned  Counties CountyIds  Latitude  Longitude  ArchiveYear
# 618      83733.0    Lassen        18  40.07045 -120.14013         2017
# 619      83120.0     Modoc        25   0.00000    0.00000         2017
# 620      81826.0  Mariposa        22  37.61757 -120.21321         2017
# 621      78698.0  Siskiyou        47  41.84100 -123.47400         2017
# 626      48889.0     Kings        16  35.93273 -120.20014         2017

# %%
df3.head()
# Out:
#         Counties  ArchiveYear  Area (acres)
# 85338  El Dorado         2018       1004153
# 85339  El Dorado         2018            46
# 85340  El Dorado         2018            16
# 85341  El Dorado         2018            33
# 85342  El Dorado         2018            38

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2595 entries, 16 to 2086
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            2595 non-null   int64
#  1   CountyIds       2595 non-null   int64
#  2    Crop Name      2595 non-null   object
#  3    Production     2595 non-null   float64
#  4    Unit           2595 non-null   object
#  5   Price P/I ($)   2595 non-null   float64
#  6    Price P/U      2595 non-null   float64
#  7   Total Value($)  2595 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 182.5+ KB

# %%
df2['Counties'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 989 entries, 618 to 1635
# Series name: Counties
# Non-Null Count  Dtype
# --------------  -----
# 989 non-null    object
# dtypes: object(1)
# memory usage: 15.5+ KB

# %%
df3["Counties"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 87608 entries, 85338 to 172945
# Series name: Counties
# Non-Null Count  Dtype
# --------------  -----
# 87608 non-null  object
# dtypes: object(1)
# memory usage: 1.3+ MB

# %%
merged_df1 = pd.merge(df2, df3, on=["Counties",'ArchiveYear'])

df1.to_csv('/content/drive/MyDrive/Project4/2017-2019_California_Agriculture_Cleaned.csv')
merged_df.to_csv('/content/drive/MyDrive/Project4/2018_California_Farmland_Fire_Acres_Burned.csv')

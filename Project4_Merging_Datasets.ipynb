# %%
#Import Dependencies
import pandas as pd

# %%
path1 = 'Resources/2017-2019_California_Agriculture_Census_Cleaned.csv'
path2 = 'Resources/California_Fire_Incidents_Cleaned.csv'

df1 = pd.DataFrame(pd.read_csv(path1))
df2 = pd.DataFrame(pd.read_csv(path2))

# %%
df1.head()
# Out:
#    Unnamed: 0  Year   County Code     Crop Name   Production   Unit  \
# 0          16  2017             7  ALMONDS ALL       29700.0  Tons
# 1          18  2017            11  ALMONDS ALL       64200.0  Tons
# 2          19  2017            19  ALMONDS ALL      258000.0  Tons
# 3          20  2017            21  ALMONDS ALL       44200.0  Tons
# 4          21  2017            29  ALMONDS ALL      264000.0  Tons
#
#    Price P/I ($)   Price P/U  Total Value($)
# 0           0.16     4653.03    1.381950e+08
# 1           0.07     4785.64    3.072380e+08
# 2           0.02     4526.00    1.167708e+09
# 3           0.11     4912.22    2.171200e+08
# 4           0.02     4676.98    1.234724e+09

# %%
df2.head()
